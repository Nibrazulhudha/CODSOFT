# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         Titanic Survival Prediction
#     </h3>
#     </div>

# %% [markdown]
# * **Importing Libraries and Loading Data**
#
# * **Data Information and Data Cleaning**
#
# * **Building The Model**
#
# * **Conclusion**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot, plot
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# **Data Visulization**

# %%
#draw a bar plot of survival by sex
sns.barplot(x="Sex", y="Survived", data=df)
#print percentages of females vs. males that survive
print("Percentage of females who survived:", df["Survived"][df["Sex"] =='female'])

print("Percentage of males who survived:",df["Survived"][df["Sex"] =='male'])
# Out:
# Percentage of females who survived: 1      1
# 4      1
# 6      1
# 8      1
# 12     1
#       ..
# 409    1
# 410    1
# 411    1
# 412    1
# 414    1
# Name: Survived, Length: 152, dtype: int64
# Percentage of males who survived: 0      0
# 2      0
# 3      0
# 5      0
# 7      0
#       ..
# 407    0
# 413    0
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 266, dtype: int64

# %%
#draw a bar plot of survival by Pclass
sns.barplot(x="Pclass", y="Survived", data=df)

#print percentage of people by Pclass that survived
print("Percentage of Pclass = 1 who survived:", df["Survived"][df["Pclass"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 2 who survived:", df["Survived"][df["Pclass"] == 2].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 3 who survived:", df["Survived"][df["Pclass"] == 3].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of Pclass = 1 who survived: 46.728971962616825
# Percentage of Pclass = 2 who survived: 32.25806451612903
# Percentage of Pclass = 3 who survived: 33.02752293577982

# %%
#draw a bar plot for SibSp vs. survival
sns.barplot(x="SibSp", y="Survived", data=df)

#I won't be printing individual percent values for all of these.
print("Percentage of SibSp = 0 who survived:", df["Survived"][df["SibSp"] == 0].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 1 who survived:", df["Survived"][df["SibSp"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 2 who survived:", df["Survived"][df["SibSp"] == 2].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of SibSp = 0 who survived: 31.09540636042403
# Percentage of SibSp = 1 who survived: 49.09090909090909
# Percentage of SibSp = 2 who survived: 42.857142857142854

# %%
#draw a bar plot for Parch vs. survival
sns.barplot(x="Parch", y="Survived", data=df)
plt.show()

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         Data Information and Data Cleaning
#     </h3>
#     </div>

# %%
def missing_values_percent(dataframe):
    missing_values = dataframe.isna().sum()
    percentage_missing = (missing_values / len(dataframe) * 100).round(2)

    result_movie = pd.DataFrame({'Missing Values': missing_values, 'Percentage': percentage_missing})
    result_movie['Percentage'] = result_movie['Percentage'].astype(str) + '%'

    return result_movie


result = missing_values_percent(df)
result
# Out:
#              Missing Values Percentage
# PassengerId               0       0.0%
# Survived                  0       0.0%
# Pclass                    0       0.0%
# Name                      0       0.0%
# Sex                       0       0.0%
# Age                      86     20.57%
# SibSp                     0       0.0%
# Parch                     0       0.0%
# Ticket                    0       0.0%
# Fare                      1      0.24%
# Cabin                   327     78.23%
# Embarked                  0       0.0%

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name  Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)    0  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...    0  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    0  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild    0  22.0      0
# 28                            Brady, Mr. John Bertram    1  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 26      1       113509   61.9792              B36        C
# 28      0       113054   30.5000              A21        S

# %%
df['Age'] = df['Age'].round().astype(int)

# %%
df['Fare'] = df['Fare'].round().astype(int)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name  Sex  Age  SibSp  Parch  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)    0   23      1      0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...    0   47      1      0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    0   48      1      3
# 26                       Ostby, Miss. Helene Ragnhild    0   22      0      1
# 28                            Brady, Mr. John Bertram    1   41      0      0
#
#          Ticket  Fare            Cabin Embarked
# 12        21228    82              B45        S
# 14  W.E.P. 5734    61              E31        S
# 24     PC 17608   262  B57 B59 B63 B66        C
# 26       113509    62              B36        C
# 28       113054    30              A21        S

# %%
df.drop(['PassengerId','Name','Ticket','Cabin', 'Embarked'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 12 to 414
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  87 non-null     int64
#  1   Pclass    87 non-null     int64
#  2   Sex       87 non-null     int64
#  3   Age       87 non-null     int64
#  4   SibSp     87 non-null     int64
#  5   Parch     87 non-null     int64
#  6   Fare      87 non-null     int64
# dtypes: int64(7)
# memory usage: 5.4 KB

# %%
#draw a bar plot of survival by sex
sns.barplot(x="Sex", y="Survived", data=df)

#print percentages of females vs. males that survive
print("Percentage of females who survived:", df["Survived"][df["Sex"] == 'female'].value_counts)

print("Percentage of males who survived:", df["Survived"][df["Sex"] == 'male'].value_counts)
# Out:
# Percentage of females who survived: <bound method IndexOpsMixin.value_counts of Series([], Name: Survived, dtype: int64)>
# Percentage of males who survived: <bound method IndexOpsMixin.value_counts of Series([], Name: Survived, dtype: int64)>

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         Building Model
#     </h3>
#     </div>

# %%
X = df.drop('Survived', axis=1)
y = df['Survived']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (69, 6)
# (69, 1)
# (18, 6)
# (18, 1)

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=6))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                70
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
past = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 179ms/step - loss: 0.3974 - mean_absolute_error: 0.5237 - val_loss: 0.3189 - val_mean_absolute_error: 0.4341
# Epoch 2/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3854 - mean_absolute_error: 0.5184 - val_loss: 0.3087 - val_mean_absolute_error: 0.4269
# Epoch 3/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3735 - mean_absolute_error: 0.5127 - val_loss: 0.2989 - val_mean_absolute_error: 0.4212
# Epoch 4/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3614 - mean_absolute_error: 0.5073 - val_loss: 0.2893 - val_mean_absolute_error: 0.4161
# Epoch 5/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3507 - mean_absolute_error: 0.5026 - val_loss: 0.2798 - val_mean_absolute_error: 0.4107
# Epoch 6/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.3398 - mean_absolute_error: 0.4973 - val_loss: 0.2705 - val_mean_absolute_error: 0.4052
# Epoch 7/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3284 - mean_absolute_error: 0.4913 - val_loss: 0.2614 - val_mean_absolute_error: 0.3995
# Epoch 8/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.3182 - mean_absolute_error: 0.4856 - val_loss: 0.2524 - val_mean_absolute_error: 0.3939
# Epoch 9/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3071 - mean_absolute_error: 0.4791 - val_loss: 0.2437 - val_mean_absolute_error: 0.3882
# Epoch 10/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2976 - mean_absolute_error: 0.4730 - val_loss: 0.2350 - val_mean_absolute_error: 0.3822
# Epoch 11/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2873 - mean_absolute_error: 0.4660 - val_loss: 0.2264 - val_mean_absolute_error: 0.3759
# Epoch 12/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2771 - mean_absolute_error: 0.4589 - val_loss: 0.2178 - val_mean_absolute_error: 0.3695
# Epoch 13/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2680 - mean_absolute_error: 0.4522 - val_loss: 0.2093 - val_mean_absolute_error: 0.3628
# Epoch 14/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2581 - mean_absolute_error: 0.4445 - val_loss: 0.2010 - val_mean_absolute_error: 0.3558
# Epoch 15/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2489 - mean_absolute_error: 0.4372 - val_loss: 0.1930 - val_mean_absolute_error: 0.3488
# Epoch 16/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2397 - mean_absolute_error: 0.4295 - val_loss: 0.1852 - val_mean_absolute_error: 0.3418
# Epoch 17/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2307 - mean_absolute_error: 0.4216 - val_loss: 0.1777 - val_mean_absolute_error: 0.3345
# Epoch 18/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2215 - mean_absolute_error: 0.4129 - val_loss: 0.1705 - val_mean_absolute_error: 0.3273
# Epoch 19/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2129 - mean_absolute_error: 0.4047 - val_loss: 0.1634 - val_mean_absolute_error: 0.3202
# Epoch 20/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2045 - mean_absolute_error: 0.3957 - val_loss: 0.1564 - val_mean_absolute_error: 0.3134
# Epoch 21/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1962 - mean_absolute_error: 0.3871 - val_loss: 0.1496 - val_mean_absolute_error: 0.3068
# Epoch 22/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1880 - mean_absolute_error: 0.3782 - val_loss: 0.1430 - val_mean_absolute_error: 0.3002
# Epoch 23/50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1808 - mean_absolute_error: 0.3702 - val_loss: 0.1365 - val_mean_absolute_error: 0.2935
# Epoch 24/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1731 - mean_absolute_error: 0.3615 - val_loss: 0.1303 - val_mean_absolute_error: 0.2869
# Epoch 25/50
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1658 - mean_absolute_error: 0.3532 - val_loss: 0.1243 - val_mean_absolute_error: 0.2804
# Epoch 26/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1592 - mean_absolute_error: 0.3453 - val_loss: 0.1183 - val_mean_absolute_error: 0.2738
# Epoch 27/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1525 - mean_absolute_error: 0.3374 - val_loss: 0.1126 - val_mean_absolute_error: 0.2672
# Epoch 28/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1457 - mean_absolute_error: 0.3291 - val_loss: 0.1071 - val_mean_absolute_error: 0.2608
# Epoch 29/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1395 - mean_absolute_error: 0.3210 - val_loss: 0.1018 - val_mean_absolute_error: 0.2543
# Epoch 30/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1336 - mean_absolute_error: 0.3130 - val_loss: 0.0967 - val_mean_absolute_error: 0.2479
# Epoch 31/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1276 - mean_absolute_error: 0.3049 - val_loss: 0.0918 - val_mean_absolute_error: 0.2414
# Epoch 32/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1223 - mean_absolute_error: 0.2972 - val_loss: 0.0871 - val_mean_absolute_error: 0.2349
# Epoch 33/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1168 - mean_absolute_error: 0.2895 - val_loss: 0.0827 - val_mean_absolute_error: 0.2285
# Epoch 34/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1118 - mean_absolute_error: 0.2825 - val_loss: 0.0785 - val_mean_absolute_error: 0.2222
# Epoch 35/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1069 - mean_absolute_error: 0.2749 - val_loss: 0.0746 - val_mean_absolute_error: 0.2159
# Epoch 36/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1021 - mean_absolute_error: 0.2679 - val_loss: 0.0708 - val_mean_absolute_error: 0.2098
# Epoch 37/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0977 - mean_absolute_error: 0.2608 - val_loss: 0.0672 - val_mean_absolute_error: 0.2033
# Epoch 38/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0933 - mean_absolute_error: 0.2542 - val_loss: 0.0638 - val_mean_absolute_error: 0.1970
# Epoch 39/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0893 - mean_absolute_error: 0.2477 - val_loss: 0.0606 - val_mean_absolute_error: 0.1912
# Epoch 40/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0856 - mean_absolute_error: 0.2415 - val_loss: 0.0576 - val_mean_absolute_error: 0.1854
# Epoch 41/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0820 - mean_absolute_error: 0.2352 - val_loss: 0.0546 - val_mean_absolute_error: 0.1793
# Epoch 42/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0784 - mean_absolute_error: 0.2288 - val_loss: 0.0520 - val_mean_absolute_error: 0.1736
# Epoch 43/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0750 - mean_absolute_error: 0.2228 - val_loss: 0.0496 - val_mean_absolute_error: 0.1680
# Epoch 44/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0717 - mean_absolute_error: 0.2170 - val_loss: 0.0473 - val_mean_absolute_error: 0.1624
# Epoch 45/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0689 - mean_absolute_error: 0.2120 - val_loss: 0.0452 - val_mean_absolute_error: 0.1570
# Epoch 46/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0659 - mean_absolute_error: 0.2064 - val_loss: 0.0433 - val_mean_absolute_error: 0.1525
# Epoch 47/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0629 - mean_absolute_error: 0.2013 - val_loss: 0.0416 - val_mean_absolute_error: 0.1484
# Epoch 48/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0602 - mean_absolute_error: 0.1959 - val_loss: 0.0400 - val_mean_absolute_error: 0.1448
# Epoch 49/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0576 - mean_absolute_error: 0.1906 - val_loss: 0.0385 - val_mean_absolute_error: 0.1422
# Epoch 50/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0554 - mean_absolute_error: 0.1855 - val_loss: 0.0372 - val_mean_absolute_error: 0.1399

# %%
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7d380a919000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 63ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score is:",R2 )
# Out:
# R2 Score is: 0.896891654638126
